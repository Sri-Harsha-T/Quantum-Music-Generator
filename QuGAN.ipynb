# %%
# !pip install git+https://github.com/PennyLaneAI/pennylane
# Out:
# Collecting git+https://github.com/PennyLaneAI/pennylane
#   Cloning https://github.com/PennyLaneAI/pennylane to c:\users\sriha\appdata\local\temp\pip-req-build-b9lxnzy1
#   Resolved https://github.com/PennyLaneAI/pennylane to commit 595ce24c9cf04c1b7f3280ca14336f5b21c47ecf
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting dill
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
# Requirement already satisfied: toml in c:\users\sriha\anaconda3\lib\site-packages (from PennyLane==0.27.0.dev0) (0.10.2)
# Requirement already satisfied: numpy in c:\users\sriha\anaconda3\lib\site-packages (from PennyLane==0.27.0.dev0) (1.21.5)
# Requirement already satisfied: scipy in c:\users\sriha\anaconda3\lib\site-packages (from PennyLane==0.27.0.dev0) (1.7.3)
# Collecting retworkx
#   Downloading retworkx-0.12.0-py3-none-any.whl (10 kB)
# Collecting semantic-version>=2.7
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting autograd
#   Using cached autograd-1.5-py3-none-any.whl (48 kB)
# Requirement already satisfied: cachetools in c:\users\sriha\anaconda3\lib\site-packages (from PennyLane==0.27.0.dev0) (4.2.2)
# Requirement already satisfied: networkx in c:\users\sriha\anaconda3\lib\site-packages (from PennyLane==0.27.0.dev0) (2.7.1)
# Collecting pennylane-lightning>=0.26
#   Downloading PennyLane_Lightning-0.26.1-cp39-cp39-win_amd64.whl (4.4 MB)
# Requirement already satisfied: appdirs in c:\users\sriha\anaconda3\lib\site-packages (from PennyLane==0.27.0.dev0) (1.4.4)
# Collecting autoray>=0.3.1
#   Using cached autoray-0.5.1-py3-none-any.whl (37 kB)
# Requirement already satisfied: requests in c:\users\sriha\anaconda3\lib\site-packages (from PennyLane==0.27.0.dev0) (2.27.1)
# Collecting zstd
#   Downloading zstd-1.5.2.6-cp39-cp39-win_amd64.whl (148 kB)
# Collecting ninja
#   Using cached ninja-1.10.2.4-py2.py3-none-win_amd64.whl (293 kB)
# Requirement already satisfied: future>=0.15.2 in c:\users\sriha\anaconda3\lib\site-packages (from autograd->PennyLane==0.27.0.dev0) (0.18.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sriha\anaconda3\lib\site-packages (from requests->PennyLane==0.27.0.dev0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sriha\anaconda3\lib\site-packages (from requests->PennyLane==0.27.0.dev0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sriha\anaconda3\lib\site-packages (from requests->PennyLane==0.27.0.dev0) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sriha\anaconda3\lib\site-packages (from requests->PennyLane==0.27.0.dev0) (3.3)
# Collecting rustworkx==0.12.0
#   Downloading rustworkx-0.12.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Building wheels for collected packages: PennyLane
#   Building wheel for PennyLane (PEP 517): started
#   Building wheel for PennyLane (PEP 517): finished with status 'done'
#   Created wheel for PennyLane: filename=PennyLane-0.27.0.dev0-py3-none-any.whl size=1130081 sha256=abaa3505d2f0b5486c455abe3157e060871bb5edee25f4ba8b88562b7e8963f2
#   Stored in directory: C:\Users\sriha\AppData\Local\Temp\pip-ephem-wheel-cache-d4r7lsex\wheels\ff\98\7f\b2d5531cd099e9cf4a7f4098f7fe1c7eca2f285847a57dbdb4
# Successfully built PennyLane
# Installing collected packages: rustworkx, ninja, zstd, semantic-version, retworkx, pennylane-lightning, dill, autoray, autograd, PennyLane
# Successfully installed PennyLane-0.27.0.dev0 autograd-1.5 autoray-0.5.1 dill-0.3.6 ninja-1.10.2.4 pennylane-lightning-0.26.1 retworkx-0.12.0 rustworkx-0.12.0 semantic-version-2.10.0 zstd-1.5.2.6
#   Running command git clone -q https://github.com/PennyLaneAI/pennylane 'C:\Users\sriha\AppData\Local\Temp\pip-req-build-b9lxnzy1'

# %%
import pennylane as qml

from pennylane.templates.layers import BasicEntanglerLayers, StronglyEntanglingLayers, RandomLayers
from pennylane.templates.embeddings import AmplitudeEmbedding
from pennylane import numpy as np
import torch
from music21 import converter, instrument,  note, chord, stream

from pathlib import Path
import pickle, glob
# import numpy

# %%
n_wires = 12
wires_range = range(n_wires)

n_note_encoding = 7
encoding_range = range(n_note_encoding)

dev = qml.device('default.qubit', wires=n_wires)

running_dev = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
running_dev
# Out:
# device(type='cuda')

# %%
from msilib import sequence


notes_dir = 'notes.pk'
frequencies_dir = 'frequencies.pk'


class Midi:

    def __init__(self, seq_length, device):
        self.seq_length = seq_length
        self.device = device

        if Path(notes_dir).is_file():
            self.notes = pickle.load(open(notes_dir, 'rb'))
            self.frequencies = pickle.load(open(frequencies_dir, 'rb'))
            # print(self.notes)
            # print(self.frequencies)
        else:
            self.notes, self.frequencies = self.get_notes()
            # print(self.notes)
            # print(self.frequencies)
            pickle.dump(self.notes, open(notes_dir, 'wb'))
            pickle.dump(self.frequencies, open(frequencies_dir, 'wb'))

        self.network_input, self.network_output = self.prepare_sequences(self.notes, self.frequencies)
        print(f"Input shape: {self.network_input.shape}")
        print(f"Output shape: {self.network_output.shape}")


    def lazy_superimpose(self, input_chord):
        frequencies = np.array([note.pitch.frequency for note in input_chord.notes])
        return np.average(frequencies, axis=0)

    def get_notes(self):
        '''Get all the notes and chords from the midi files in the ./midi_song directory'''
        # This is assuming that every interval between notes is the same (0.5)
        notes = []
        frequencies = []

        for file in glob.glob("midi_songs/*.mid"):
            midi = converter.parse(file)

            print("Parsing %s" % file)

            notes_to_parse = None

            try:
                s2 = instrument.partitionByInstrument(midi)
                notes_to_parse = s2.parts[0].recurse()

            except:
                notes_to_parse = midi.flat.notes

            
            for element in notes_to_parse:
                if isinstance(element, note.Note):
                    notes.append(str(element.pitch))
                    frequencies.append(element.pitch.frequency)
                elif isinstance(element, chord.Chord):
                    notes.append(".".join(str(n) for n in element.normalOrder))
                    frequencies.append(self.lazy_superimpose(element))
                # print(element)
        # print("Notes:", notes)
        # print("Freqs", frequencies)
        return notes, frequencies


    def prepare_sequences(self, notes, frequencies):
        '''Prepare the sequences used by the Neural Network'''

        # Order pitchnames by their frequencties, so that the mse loss makes more sense
        pitchnames = list(dict.fromkeys([x for _, x in sorted(zip(frequencies, notes))]))

        # Dicttionary to map pitches to integers
        self.note_to_int = {note : number for number, note in enumerate(pitchnames)}
        self.int_to_note = {number: note for number, note in enumerate(pitchnames)}

        network_input = []
        network_output = []

        # Create inoput sequences and the corresponding outpus 
        for i in range(len(self.notes) - self.seq_length):
            sequence_in = self.notes[i : i + self.seq_length]
            sequence_out = self.notes[ i + self.seq_length]
            network_input.append([self.note_to_int[char] for char in sequence_in])
            network_output.append(self.note_to_int[sequence_out])


        n_patterns = len(network_input)
        # print(n_patterns)

        # reshape the input into a format compatible with LSTM Layers
        # This is really (no. diff inputs, sequence length, no. of features)
        network_input = np.reshape(network_input, (n_patterns, self.seq_length))
        # print(network_input.shape)
        network_input = network_input.tolist()

        network_input = torch.tensor(network_input, device=self.device, dtype=torch.double)
        network_output = torch.tensor(network_output, device=self.device)

        self.input_norms = torch.tensor(torch.linalg.norm(network_input, axis=1))

        return (
            network_input, 
            network_output,
        ) 



    def create_midi_from_model(self, prediction_output, filename):
        '''convert the output from the prediction to notes and create a midi file from the notes'''
        offset = 0
        output_notes = []

        # Create note and chord objects based on the values generated by the model
        for pattern in prediction_output:
            # pattern is a chord
            if ("." in pattern) or pattern.isdigit():
                notes_in_chord = pattern.split(".")
                notes = []
                for current_note in notes_in_chord:
                    new_note=  note.Note(int(current_note))
                    new_note.storedInstrument = instrument.Piano()
                    notes.append(new_note)
                new_chord = chord.Chord(notes)
                new_chord.offset = offset
                output_notes.append(new_chord)
            # pattern is a note
            else:
                new_note = note.Note(pattern)
                new_note.offset = offset
                new_note.storedInstrument = instrument.Piano()
                output_notes.append(new_note)
            
            # increase offset each iteration so that notes do not stack
            offset += 0.5

        midi_stream = stream.Stream(output_notes)

        midi_stream.write("midi", fp=filename)

# %%
seq_length = 2**n_note_encoding
print("Initialized Midi")
midi = Midi(seq_length, running_dev)
# notes = pickle.load(open(notes_dir, 'rb'))
# print(notes)
# freqs = pickle.load(open(frequencies_dir, 'rb'))
# print(freqs)
# Out:
# Initialized Midi
# Input shape: torch.Size([4877, 128])
# Output shape: torch.Size([4877])
# C:\Users\sriha\AppData\Local\Temp\ipykernel_11532\2989763024.py:102: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.input_norms = torch.tensor(torch.linalg.norm(network_input, axis=1))

# %%
def encode_music(notes):
    AmplitudeEmbedding(features=notes, wires=encoding_range, normalize=True)

def music_generator(weights):
    # StronglyEntanglingLayers(weights, wires=encoding_range)
    # BasicEntanglerLayers(weights, wires=encoding_range)
    RandomLayers(weights, wires=encoding_range)

def discriminator(weights):
    # BasicEntanglerLayers(weights, wires=wires_range)
    StronglyEntanglingLayers(weights, wires=wires_range)

def measurement(wire_count):
    obs = qml.PauliZ(0)
    for i in range(1, wire_count):
        obs = obs @ qml.PauliZ(i)
    return qml.expval(obs)

# %%
@qml.qnode(dev, interface='torch')
def real_music_dicriminator(inputs, weights):
    encode_music(inputs)
    discriminator(weights)
    return measurement(n_note_encoding)

def music_generator_circuit(inputs, note_weights):
    encode_music(inputs)
    music_generator(note_weights)

@qml.qnode(dev, interface='torch')
def generated_music_dicriminator(inputs, note_weights, weights):
    music_generator_circuit(inputs, note_weights)
    discriminator(weights)
    return measurement(n_note_encoding)

# %%
n_disc_layers = 12
n_gen_layers = 20

real_shapes = {'weights': (n_disc_layers, n_wires, 3)}
real_layer  = qml.qnn.TorchLayer(real_music_dicriminator, real_shapes).to(running_dev)

generated_shapes = {
    'weights': (n_disc_layers, n_wires, 3), 
    'note_weights': (n_gen_layers, n_note_encoding),
}

generated_layer = qml.qnn.TorchLayer(generated_music_dicriminator, generated_shapes).to(running_dev)
generated_layer.weights.requires_grad = False

# %%
def sync_weights(source_layer, target_layer):
    '''Synchronize the weights of two layers'''
    source_weights = source_layer.weights
    target_weights = target_layer.weights
    with torch.no_grad():
        for source_weight, target_weight in zip(source_weights, target_weights):
            target_weight.data = source_weight.data

# %%
def prob_fun_disc_true(layer):
    def prob_true(inputs):
        true_output = layer(inputs)
        # Convert to probability
        prob_true = (true_output + 1)/2
        return prob_true
        
    return prob_true

# %%
prob_real_true = prob_fun_disc_true(real_layer)
prob_gen_true = prob_fun_disc_true(generated_layer)

empty_input = torch.tensor(np.zeros((1, )).tolist()).to(running_dev)

def disc_cost(inputs):
    return prob_gen_true(inputs) - prob_real_true(inputs)

def gen_cost(inputs):
    return -prob_gen_true(inputs)

# %%
def gen_batch_inputs(batch_size=1):
    return midi.network_input[np.random.randint(0, len(midi.network_input), size=batch_size)
    ]

def shuffle_music(datapoint):
    return datapoint[torch.randperm(datapoint.size()[0])].detach()

# %%
def discriminator_iteration(n_iterations, learning_rate):

    opt = torch.optim.Adam(real_layer.parameters(), lr=learning_rate)
    best_cost = disc_cost(midi.network_input[0])

    for _ in range(n_iterations):
        opt.zero_grad()
        # Sample a batch of data
        batch_inputs = gen_batch_inputs()
        batch_inputs = batch_inputs.detach()
        # Compute the loss
        loss = disc_cost(batch_inputs)
        sync_weights(real_layer, generated_layer)
        # Backpropagate the loss
        loss.backward()
        # Update the weights
        opt.step()
        # Update the best cost
        if loss < best_cost:
            best_cost = loss
        print('New Best Discriminator Cost:', best_cost)

# %%
def generator_iteration(n_iterations, learning_rate):
    opt = torch.optim.SGD(filter(lambda p: p.requires_grad, generated_layer.parameters()), lr=learning_rate)
    best_cost = gen_cost(midi.network_input[0])

    for _ in range(n_iterations):
        opt.zero_grad()
        # Compute the loss

        batch_inputs = gen_batch_inputs()
        batch_inputs = shuffle_music(batch_inputs)

        # print(generated_layer.note_weights)

        loss = gen_cost(batch_inputs)
        # Backpropagate the loss
        loss.backward()
        # Update the weights
        opt.step()
        # Upadate the best cost
        if loss < best_cost :
            best_cost = loss

    print('New Best Generator Cost:', best_cost)

# %%
# The real iteration
steps = 100
n_iterations = 20
learning_rate = 0.1
# batch_size = 3

generation_counter = 0

model_name = f"quGan-qu{n_wires}-quen{n_note_encoding}-step{steps}-iter{n_iterations}"
model_str = f"{model_name}.pt"

if Path(model_str).is_file():
    print("Loading model")
    generated_layer.load_state_dict(torch.load(model_str))
    generated_layer.eval()
else:
    # print("Training model")
    for _ in range(steps):
        discriminator_iteration(n_iterations, learning_rate)
        # sync_weights(real_layer, generated_layer)
        generator_iteration(n_iterations, learning_rate)
    torch.save(generated_layer.state_dict(), model_str)
# Out:
# New Best Discriminator Cost: tensor(0.0113, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.0381, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.0688, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.0891, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1066, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1236, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1356, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1446, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1532, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1630, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1733, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1786, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1844, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1910, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1945, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1960, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1988, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2032, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2066, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2095, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5141, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.2040, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2040, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2040, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2040, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2040, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2040, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2040, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2040, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2040, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2040, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2040, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2059, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2108, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2151, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2179, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2188, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2203, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2227, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2259, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2293, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5242, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.2231, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2231, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2231, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2231, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2231, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2231, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2231, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2231, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2231, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2231, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2231, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2231, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2231, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2231, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2231, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2231, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2231, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2236, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2253, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2269, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5236, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.2214, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2214, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2214, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2214, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2214, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2214, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2214, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2214, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2214, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2214, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2214, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2214, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2214, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2214, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2214, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2214, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2214, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2215, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2225, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2247, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5333, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2201, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2204, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5438, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.2168, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2168, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2168, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2168, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2168, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2168, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2168, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2168, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2168, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2168, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2168, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2168, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2168, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2168, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2168, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2168, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2168, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2168, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2170, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2186, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5423, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2156, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2160, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5435, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2134, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5525, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2120, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5522, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2083, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2092, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5513, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2073, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5564, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2063, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5563, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.2020, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2020, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2020, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2020, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2020, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2020, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2020, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2020, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2020, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2020, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2020, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2020, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2020, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2020, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2020, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2020, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2020, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2020, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2022, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2022, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5587, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2013, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2024, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5603, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.2010, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5637, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5632, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1994, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5641, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5652, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1964, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1976, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5661, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5672, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1959, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5682, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.1948, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1948, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1948, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1948, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1948, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1948, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1948, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1948, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# ...
# New Best Discriminator Cost: tensor(-0.1810, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5924, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5933, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.1803, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1803, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1803, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1803, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1803, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1803, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1803, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1803, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1803, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1803, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1803, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1803, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1803, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1803, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1803, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1803, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1803, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1803, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1815, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1828, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5944, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1818, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5913, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1806, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5915, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1790, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5927, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1793, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5918, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Discriminator Cost: tensor(-0.1789, device='cuda:0', dtype=torch.float64, grad_fn=<SubBackward0>)
# New Best Generator Cost: tensor(-0.5954, device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)

# %%
import random

def generate_notes(model, network_input, int_to_note, n_notes):
    '''Generate notes from the neural network based on a sequence of notes'''
    # pick a random sequence from the input as a starting point for the prediction
    scale_factor = len(midi.int_to_note) / torch.max(midi.input_norms)
    with torch.no_grad():
        start = random.randint(0, len(network_input) - n_notes)

        prediction_output = []


        # generate n_notes

        for i in range(start, start + n_notes):
            input_ = network_input[i]
            generated_note = model(shuffle_music(input_))
            generated_note = (generated_note + 1) * midi.input_norms[i]
            generated_note = int(generated_note)
            counter = 1
            while generated_note not in int_to_note:
                generated_note *= counter/(counter+1)
                generated_note = int(generated_note)
                counter += 1

            result = int_to_note[int(generated_note)]
            prediction_output.append(result)

        return prediction_output

# %%
@qml.qnode(dev, interface='torch')
def final_music_generator(inputs, note_weights):
    music_generator_circuit(inputs, note_weights)
    return measurement(n_note_encoding)

# %%
# generator_only = qml.QNode(final_music_generator, dev, interface='torch')
weight_gens = {
    'note_weights':(n_gen_layers, n_note_encoding),
}
generator_only_layer = qml.qnn.TorchLayer(final_music_generator, weight_gens).to(running_dev)

# %%
def sync_final_weights(source_layer, target_layer):
    '''Synchronize the weights of two layers'''
    source_weights = source_layer.note_weights
    target_weights = target_layer.note_weights
    with torch.no_grad():
        for source_weight, target_weight in zip(source_weights, target_weights):
            target_weight.data = source_weight.data

# %%
n_notes = 200
generated_notes = []
print('Generating Notes')
print(midi.input_norms.shape)
sync_final_weights(generated_layer, generator_only_layer)
notes = generate_notes(generator_only_layer, midi.network_input, midi.int_to_note, n_notes=n_notes)
# notes
# Out:
# Generating Notes
# torch.Size([4877])

# %%
generation_counter += 1
print('Saving as MIDI file')
midi.create_midi_from_model(notes, f'{model_name}_generated_{generation_counter}.mid')
# Out:
# Saving as MIDI file
